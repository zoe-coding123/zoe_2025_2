# %%
---
toc: true
layout: post
title: adventureGame Changes
description: A summary of my game changes and process.
categories: [Final Review]
author: Zoe Chow
---

# %% [markdown]
# 2/6/25
#
# I started creating a new level for the game. I renamed the original GameLevelDesert to GameLevelMap and made another file for a desert level. I also added in the background image for that level.
#
# ![Image](https://github.com/user-attachments/assets/c3c4e013-1813-49b6-a5eb-c80c6e9aa6e7)
#
# 2/7/25
#
# I added in a function and made a flip property for npcs to flip the robot sprite for GameLevelDesert to face the other direction so that it would be facing towards the player.
#
# This is the code of the function in Character.js
# ![Image](https://github.com/user-attachments/assets/59dcde44-144b-4ffe-b062-1546f71d7f7a)
#
# Here is the flip property in the sprite data for the robot in GameLevelDesert
# ![Image](https://github.com/user-attachments/assets/e9d3ab39-93eb-4aa0-91b9-037ff996840e)
#
# Then I made a mountain level.
#
# 2/7 - 2/10
#
# After making the mountain level I made the ice level. Then for each level besides the map level I changed the starting location of the player to line up with the ground.
#
# Then I added this conditional into the handleKeyDown function in Player.js to restrict the movement of the player so they can only move side to side in all the other levels except GameLevelMap.
# ![Image](https://github.com/user-attachments/assets/150a2b22-9a29-451a-b7a5-b1505214ea15)
# This was so the player can only walk on the ground and not into the sky.
#
# 2/10 - 2/12
#
# I changed the locations of the npcs on the map to be in different areas that correspond to the level they're in.
#
# Before
# ![Image](https://github.com/user-attachments/assets/df3a64bd-0f5a-434f-9c9d-d8776b1d4096)
#
# After
# ![Image](https://github.com/user-attachments/assets/0cafc81a-bb10-4b68-af8e-edd7e416be6a)
#
# Additionally I ended up creating a BackgroundObject class for the ice under the Tux npc.
# ![Image](https://github.com/user-attachments/assets/3e85c3da-dd25-4101-83a2-1f0b1e1e03a2)
# ![Image](https://github.com/user-attachments/assets/20ca506e-ed27-4ef2-8e0d-c1c40582bd50)
#
# 2/12 - 2/20
#
# Over the next few days I worked on making it so when the player gets close to the npc on the map, they will get transported to the corresponding level for the area.
#
# I had to create an empty transitionNPCS property in GameControl, and also ended up having to change the way I had the npcs defined in GameLevelMap.
#
# ![Image](https://github.com/user-attachments/assets/50bd7b19-2bcd-43b9-8013-1a79e35155fa)
#
# Then I had to add the targetLevel property to the sprite data for GameLevelMap, and edit Npc.js so that all Npcs have the targetLevel property. This has the level that the sprite's dimensions/hitbox should trigger the transition to. For this I also had to add a name property to each of the game levels.
#
# The rest of the changes were in GameControl, where transitionNPCS and targetLevel would now be used/referenced.
#
# These are the new functions I added, handleNPCTransition for the actual level transitions and checkTransitions to see if the player is in the transition areas and then run handleNPCTransition.
# ![Image](https://github.com/user-attachments/assets/a2c21545-4162-4ebd-901e-7bf88e2d8879)
# ![Image](https://github.com/user-attachments/assets/bf629dd2-83db-44ec-97cf-e8ecd031e3ed)
#
# I also had to edit loadLevel and loadLevelObjects to have transitionNPCS and to load the targetLevel.
# ![Image](https://github.com/user-attachments/assets/b36b173a-517a-4727-8d7e-a578d62ce8b1)
# ![Image](https://github.com/user-attachments/assets/93a185d8-8d40-4f42-9e5e-07f2e178bd20)
#
# I also had to add checkTransitions to be used in the gameLoop. I had to do a lot of troubleshooting trying and testing different things before I got it to work.
#
# While troubleshooting I had to add to/edit Npc.js in order to resolve the sprites being made twice and to fix the collisions between the player and the npc transition areas which wasn't working before.
# ![Image](https://github.com/user-attachments/assets/8f34f60e-a3c7-466e-8e3a-958d183267dc)
# Here the npcs now get assigned a new unique id each time they're made, as part of the issue seemed to be because of duplicate ids/objects. As well as the additional hitbox calculations and collision dimensions since the hitbox values had been coming back as 0 before.
#
# I also had to do the something similar in Player.js
# ![Image](https://github.com/user-attachments/assets/52ac4659-936b-4c48-8a93-da6fd489ca6e)
#
# 2/20 - 2/24
#
# After finishing the transitions from the map/npcs into their corresponding levels, then I worked on being able to go back after completing the quiz from the npc. Originally I was going to do more with the quiz but I ended up opting for something simpler due to time as well as it also seeming more complicated.
#
# First I worked on making a function that checked for quiz completion. Before I could do that I had to find a way to track quiz completion. So I created GameState.js
#
# ![Image](https://github.com/user-attachments/assets/0fd5b2a0-ddc5-426b-9e32-1fc9df2a24fb)
#
# quizCompleted is what is being used to track if the quiz was submitted or not. So I then added it to Prompt.js in the handleSubmit() with GameState.quizCompleted being set to true.
# ![Image](https://github.com/user-attachments/assets/f08b976e-5af7-4f89-8575-0f2d5836679c)
#
# Then I could make the checkquizCompletion function in GameControl, which ends the level if the quiz has been submitted.
# ![Image](https://github.com/user-attachments/assets/28357571-8039-4a3e-8a5e-d5f326181b56)
#
# Then I made the routeToMapLevel function to load GameLevelMap after quiz completion.
# ![Image](https://github.com/user-attachments/assets/4dcd9ad4-4d6b-4683-86dc-2f12d0f5eb87)
#
# This function just loaded the map level and destroyed the objects from the previous level. In order to have it run after quiz completion I ended up editing the gameLoop.
# ![Image](https://github.com/user-attachments/assets/f3221f6b-600e-4b73-bbc3-279b8153d966)
#
# The very last thing I finished changing was simply just adding another browser text prompt at the start of the map level with a bit of guidance/directions on what the player is supposed to do.
# ![Image](https://github.com/user-attachments/assets/4c1f818b-beee-4d06-b0dc-d714880fdf98)
#
# These were all the main changes I managed to complete with the time we had.
